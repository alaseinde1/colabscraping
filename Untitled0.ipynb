# %% [markdown]
# <a href="https://colab.research.google.com/github/alaseinde1/colabscraping/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup

# Step 1: Paste the saved HTML content here as a string
html_content = """

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="utf-8" />
    <!-- <title>Play Free Online Games | No Download | PlayGrid-X</title> -->
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PlayGrid-X | Play Free Online Games Instantly - No Download Needed</title>
<meta property="og:title" content="PlayGrid-X | Play Free Online Games Instantly - No Download Needed" />
<meta name="twitter:title" content="PlayGrid-X | Play Free Online Games Instantly - No Download Needed" />
<meta name="embedx:title" content="PlayGrid-X | Play Free Online Games Instantly - No Download Needed" />
<meta name="description" content="Discover and play the best free online games on PlayGrid-X. Enjoy action, puzzle, arcade, sports games and more — all without downloads or signups." />
<meta property="og:description" content="Discover and play the best free online games on PlayGrid-X. Enjoy action, puzzle, arcade, sports games and more — all without downloads or signups." />
<meta name="twitter:description" content="Discover and play the best free online games on PlayGrid-X. Enjoy action, puzzle, arcade, sports games and more — all without downloads or signups." />
<meta name="embedx:description" content="Discover and play the best free online games on PlayGrid-X. Enjoy action, puzzle, arcade, sports games and more — all without downloads or signups." />
<meta charset="utf-8" />
<meta name="viewport" content="width=device-width, initial-scale=1" />
<meta name="twitter:card" content="summary_large_image" />
<meta name="twitter:creator" content="info@playgridx.com" />
<meta property="og:locale" content="en-us" />
<meta property="og:site_name" content="PlayGrid-X" />
<meta name="copyright" content="PlayGrid-X" />
<meta name="theme-color" content="#007bff" />
<link rel="icon" href="https://playgridx.com/public/web/assets/images/favicon.png" />
    <meta name="keywords" content="free online games, browser games, PlayGrid-X, play now, HTML5 games">
    <link rel="canonical" href="https://playgridx.com">
    <meta property="og:url" content="https://playgridx.com">

    <meta property="og:type" content="website">
    <!-- <meta content="" name="description" />
    <meta content="playgridx" name="author" /> -->
    <meta name="csrf-token" content="Co0E1Ypa6QxVHDq1F6VStvWXefEZgwOjfIi39xTP">
    <!-- App favicon -->
    <link rel="shortcut icon" href="https://playgridx.com/public/web/assets/images/favicon.png">

    <link rel="stylesheet" href="https://playgridx.com/public/web/assets/css/vendor/bootstrap.min.css">
  <!-- fontawesome 5  -->
  <link rel="stylesheet" href="https://playgridx.com/public/web/assets/css/all.min.css">
  <!-- line-awesome webfont -->
  <link rel="stylesheet" href="https://playgridx.com/public/web/assets/css/line-awesome.min.css">
  <!-- custom select css -->
  <link rel="stylesheet" href="https://playgridx.com/public/web/assets/css/vendor/nice-select.css">
  <!-- animate css  -->
  <link rel="stylesheet" href="https://playgridx.com/public/web/assets/css/vendor/animate.min.css">
  <!-- lightcase css -->
  <link rel="stylesheet" href="https://playgridx.com/public/web/assets/css/vendor/lightcase.css">
  <!-- slick slider css -->
  <link rel="stylesheet" href="https://playgridx.com/public/web/assets/css/vendor/slick.css">
  <!-- style main css -->
  <link rel="stylesheet" href="https://playgridx.com/public/web/assets/css/main.css">


<script async data-adbreak-test="on" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9051023451381245" crossorigin="anonymous"></script>
<script>
   window.adsbygoogle = window.adsbygoogle || [];
   var adBreak = adConfig = function(o) {adsbygoogle.push(o);}
</script>
</head>

<body>
    <!-- scroll-to-top start -->
    <div class="scroll-to-top">
        <span class="scroll-icon">
          <i class="las la-arrow-up"></i>
        </span>
    </div>
    <!-- scroll-to-top end -->

    <!-- page-wrapper start -->
    <div class="page-wrapper">

        <!-- header-section start  -->
        <header class="header">
          <div class="header__bottom">
            <div class="container">
              <nav class="navbar navbar-expand-xl align-items-center">
                <a class="site-logo site-title" href="https://playgridx.com"><img src="https://playgridx.com/public/web/assets/images/logo.png" style="width: 300px;" alt="PlayGrid-X Logo"><span
                    class="logo-icon"><i class="flaticon-fire"></i></span></a>
                <button class="navbar-toggler ml-auto" type="button" data-toggle="collapse"
                  data-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false"
                  aria-label="Toggle navigation">
                  <span class="menu-toggle"></span>
                </button>
                <div class="collapse navbar-collapse" id="navbarSupportedContent">
                  <ul class="navbar-nav main-menu ml-auto">
                    <li><a href="https://playgridx.com">Home</a></li>
                    <!-- <li><a href="https://playgridx.com/blog">Blog</a></li> -->
                    <li><a href="https://playgridx.com/about">About Us</a></li>
                    <li><a href="https://playgridx.com/contact">contact</a></li>
                    <li><a href="https://playgridx.com/privacypolicy">Privacy Policy</a></li>
                  </ul>
                </div>
              </nav>
            </div>
          </div><!-- header__bottom end -->
        </header>
        <!-- header-section end  -->


        <section class="pt-150 pb-120 position-relative overflow-hidden">
    <div class="container">
        <div class="row justify-content-center">
          <div class="col-lg-5">
            <div class="section-header text-center has--bg">
              <div class="header-image"><img src="https://playgridx.com/public/web/assets/images/elements/header-el.png" alt="section header"></div>
              <h2 class="section-title">Our Games</h2>
            </div>
          </div>
        </div><!-- row end -->

        <div class="row">
            <div class="col-lg-12">
                <div class="games-search-wrapper">
                    <div class="left">
                        <form class="games-search-from" action="https://playgridx.com/search" method="get">
                            <input type="text" name="search" id="search" onkeyup="myFunction()" placeholder="Search" class="form-control style--two" autocomplete="off">
                            <button type="button"><i class="las la-search"></i></button>
                            <ul id="searchUL" style="display:none;">
                                                                    <li>
                                        <a href="https://playgridx.com/games/4">
                                            <img src="https://playgridx.com/public/uploads/thumb1739875576.png" loading="lazy" alt="image">
                                            Air Battle Mission
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/5">
                                            <img src="https://playgridx.com/public/uploads/thumb1739876186.png" loading="lazy" alt="image">
                                            Balloonpop
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/6">
                                            <img src="https://playgridx.com/public/uploads/thumb1739876405.png" loading="lazy" alt="image">
                                            Block Bracker
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/7">
                                            <img src="https://playgridx.com/public/uploads/thumb1739876576.png" loading="lazy" alt="image">
                                            Brick Out
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/8">
                                            <img src="https://playgridx.com/public/uploads/thumb1739878343.png" loading="lazy" alt="image">
                                            Car Parking Jam 3D
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/9">
                                            <img src="https://playgridx.com/public/uploads/thumb1739878496.png" loading="lazy" alt="image">
                                            Crazy Runner
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/10">
                                            <img src="https://playgridx.com/public/uploads/thumb1739878677.png" loading="lazy" alt="image">
                                            Fantasy Forest
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/11">
                                            <img src="https://playgridx.com/public/uploads/thumb1739878970.png" loading="lazy" alt="image">
                                            Fishing Frenzy
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/12">
                                            <img src="https://playgridx.com/public/uploads/thumb1739879150.png" loading="lazy" alt="image">
                                            Flight Simulator
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/13">
                                            <img src="https://playgridx.com/public/uploads/thumb1739879602.png" loading="lazy" alt="image">
                                            Four Colors
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/14">
                                            <img src="https://playgridx.com/public/uploads/thumb1739879848.png" loading="lazy" alt="image">
                                            Girl DressUp
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/15">
                                            <img src="https://playgridx.com/public/uploads/thumb1739879960.png" loading="lazy" alt="image">
                                            Knife Hit Emoji
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/16">
                                            <img src="https://playgridx.com/public/uploads/thumb1739880100.png" loading="lazy" alt="image">
                                            Ludo Multiplayer
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/17">
                                            <img src="https://playgridx.com/public/uploads/thumb1739880475.png" loading="lazy" alt="image">
                                            Mad Shark
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/18">
                                            <img src="https://playgridx.com/public/uploads/thumb1739880778.png" loading="lazy" alt="image">
                                            Ninja Run
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/19">
                                            <img src="https://playgridx.com/public/uploads/thumb1739880913.png" loading="lazy" alt="image">
                                            Ninja Run-2
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/20">
                                            <img src="https://playgridx.com/public/uploads/thumb1739881101.png" loading="lazy" alt="image">
                                            Penalty Challenge
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/21">
                                            <img src="https://playgridx.com/public/uploads/thumb1739881221.png" loading="lazy" alt="image">
                                            Quiz Game
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/22">
                                            <img src="https://playgridx.com/public/uploads/thumb1739881659.png" loading="lazy" alt="image">
                                            Ranger VS Zombies
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/23">
                                            <img src="https://playgridx.com/public/uploads/thumb1739881816.png" loading="lazy" alt="image">
                                            Shoot Robbers
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/24">
                                            <img src="https://playgridx.com/public/uploads/thumb1739881967.png" loading="lazy" alt="image">
                                            Skibidi Toilet
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/25">
                                            <img src="https://playgridx.com/public/uploads/thumb1739882107.png" loading="lazy" alt="image">
                                            Snake Go
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/26">
                                            <img src="https://playgridx.com/public/uploads/thumb1739882217.png" loading="lazy" alt="image">
                                            Speed Boat
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/27">
                                            <img src="https://playgridx.com/public/uploads/thumb1739882394.png" loading="lazy" alt="image">
                                            Stick Man
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/28">
                                            <img src="https://playgridx.com/public/uploads/thumb1739882513.png" loading="lazy" alt="image">
                                            Strike Bowling
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/29">
                                            <img src="https://playgridx.com/public/uploads/thumb1739882672.png" loading="lazy" alt="image">
                                            Tank Defender
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/30">
                                            <img src="https://playgridx.com/public/uploads/thumb1739882829.png" loading="lazy" alt="image">
                                            Tank Wars
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/31">
                                            <img src="https://playgridx.com/public/uploads/thumb1739882939.png" loading="lazy" alt="image">
                                            Water Color Sort
                                        </a>
                                    </li>
                                                                    <li>
                                        <a href="https://playgridx.com/games/32">
                                            <img src="https://playgridx.com/public/uploads/thumb1739883384.png" loading="lazy" alt="image">
                                            Zombie Shooter
                                        </a>
                                    </li>
                                                            </ul>
                        </form>
                    </div>
                </div>
            </div>
        </div>
        <!-- <div class="col-lg-4 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s"> -->
        <!-- <div class="row mt-50 mb-none-40">


                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/4" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739875576.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739875576.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Air Battle Mission</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">182</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/5" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739876186.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739876186.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Balloonpop</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">357</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/6" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739876405.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739876405.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Block Bracker</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">316</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/7" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739876576.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739876576.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Brick Out</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">81</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/8" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739878343.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739878343.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Car Parking Jam 3D</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">346</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/9" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739878496.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739878496.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Crazy Runner</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">265</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/10" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739878677.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739878677.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Fantasy Forest</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">235</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/11" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739878970.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739878970.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Fishing Frenzy</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">140</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/12" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739879150.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739879150.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Flight Simulator</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">126</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/13" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739879602.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739879602.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Four Colors</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">84</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/14" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739879848.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739879848.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Girl DressUp</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">282</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/15" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739879960.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739879960.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Knife Hit Emoji</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">216</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/16" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739880100.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739880100.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Ludo Multiplayer</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">57</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/17" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739880475.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739880475.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Mad Shark</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">109</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/18" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739880778.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739880778.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Ninja Run</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">177</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/19" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739880913.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739880913.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Ninja Run-2</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">115</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/20" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739881101.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739881101.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Penalty Challenge</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">240</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/21" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739881221.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739881221.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Quiz Game</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">242</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/22" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739881659.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739881659.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Ranger VS Zombies</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">242</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/23" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739881816.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739881816.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Shoot Robbers</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">112</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/24" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739881967.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739881967.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Skibidi Toilet</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">136</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/25" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739882107.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739882107.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Snake Go</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">316</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/26" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739882217.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739882217.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Speed Boat</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">237</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/27" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739882394.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739882394.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Stick Man</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">121</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/28" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739882513.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739882513.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Strike Bowling</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">117</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/29" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739882672.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739882672.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Tank Defender</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">187</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/30" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739882829.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739882829.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Tank Wars</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">72</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/31" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739882939.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739882939.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Water Color Sort</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">189</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>

                <div class="col-6 col-md-4 col-lg-3 mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/32" class="game-card">
                        <div class="game-card__thumb">
                            <img src="https://playgridx.com/public/uploads/banner1739883384.png" alt="image">
                        </div>
                        <div class="game-card__content">
                            <div class="">
                                <div class="game-card__info">
                                    <div class="thumb">
                                        <img src="https://playgridx.com/public/uploads/thumb1739883384.png" alt="image">
                                    </div>
                                    <div class="content">
                                        <h5 class="game-card__title">Zombie Shooter</h5>
                                        <div class="group d-flex align-items-center justify-content-start">
                                            <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                            <p class="text" style="font-size: 26px;">342</p>
                                        </div>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                    </div> -->
        <div class="row mt-50 mb-none-40">
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/air-battle-mission" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739875576.png" loading="lazy" alt="Air Battle Mission - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Air Battle Mission</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">182</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Air Battle Mission",
                    "image": "https://playgridx.com/public/uploads/thumb1739875576.png",
                    "url": "https://playgridx.com/games/air-battle-mission",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "182"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/balloonpop" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739876186.png" loading="lazy" alt="Balloonpop - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Balloonpop</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">357</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Balloonpop",
                    "image": "https://playgridx.com/public/uploads/thumb1739876186.png",
                    "url": "https://playgridx.com/games/balloonpop",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "357"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/block-bracker" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739876405.png" loading="lazy" alt="Block Bracker - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Block Bracker</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">316</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Block Bracker",
                    "image": "https://playgridx.com/public/uploads/thumb1739876405.png",
                    "url": "https://playgridx.com/games/block-bracker",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "316"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/brick-out" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739876576.png" loading="lazy" alt="Brick Out - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Brick Out</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">81</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Brick Out",
                    "image": "https://playgridx.com/public/uploads/thumb1739876576.png",
                    "url": "https://playgridx.com/games/brick-out",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "81"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/car-parking-jam-3d" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739878343.png" loading="lazy" alt="Car Parking Jam 3D - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Car Parking Jam 3D</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">346</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Car Parking Jam 3D",
                    "image": "https://playgridx.com/public/uploads/thumb1739878343.png",
                    "url": "https://playgridx.com/games/car-parking-jam-3d",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "346"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/crazy-runner" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739878496.png" loading="lazy" alt="Crazy Runner - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Crazy Runner</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">265</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Crazy Runner",
                    "image": "https://playgridx.com/public/uploads/thumb1739878496.png",
                    "url": "https://playgridx.com/games/crazy-runner",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "265"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/fantasy-forest" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739878677.png" loading="lazy" alt="Fantasy Forest - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Fantasy Forest</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">235</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Fantasy Forest",
                    "image": "https://playgridx.com/public/uploads/thumb1739878677.png",
                    "url": "https://playgridx.com/games/fantasy-forest",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "235"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/fishing-frenzy" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739878970.png" loading="lazy" alt="Fishing Frenzy - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Fishing Frenzy</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">140</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Fishing Frenzy",
                    "image": "https://playgridx.com/public/uploads/thumb1739878970.png",
                    "url": "https://playgridx.com/games/fishing-frenzy",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "140"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/flight-simulator" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739879150.png" loading="lazy" alt="Flight Simulator - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Flight Simulator</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">126</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Flight Simulator",
                    "image": "https://playgridx.com/public/uploads/thumb1739879150.png",
                    "url": "https://playgridx.com/games/flight-simulator",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "126"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/four-colors" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739879602.png" loading="lazy" alt="Four Colors - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Four Colors</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">84</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Four Colors",
                    "image": "https://playgridx.com/public/uploads/thumb1739879602.png",
                    "url": "https://playgridx.com/games/four-colors",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "84"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/girl-dressup" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739879848.png" loading="lazy" alt="Girl DressUp - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Girl DressUp</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">282</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Girl DressUp",
                    "image": "https://playgridx.com/public/uploads/thumb1739879848.png",
                    "url": "https://playgridx.com/games/girl-dressup",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "282"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/knife-hit-emoji" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739879960.png" loading="lazy" alt="Knife Hit Emoji - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Knife Hit Emoji</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">216</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Knife Hit Emoji",
                    "image": "https://playgridx.com/public/uploads/thumb1739879960.png",
                    "url": "https://playgridx.com/games/knife-hit-emoji",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "216"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/ludo-multiplayer" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739880100.png" loading="lazy" alt="Ludo Multiplayer - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Ludo Multiplayer</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">57</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Ludo Multiplayer",
                    "image": "https://playgridx.com/public/uploads/thumb1739880100.png",
                    "url": "https://playgridx.com/games/ludo-multiplayer",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "57"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/mad-shark" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739880475.png" loading="lazy" alt="Mad Shark - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Mad Shark</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">109</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Mad Shark",
                    "image": "https://playgridx.com/public/uploads/thumb1739880475.png",
                    "url": "https://playgridx.com/games/mad-shark",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "109"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/ninja-run" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739880778.png" loading="lazy" alt="Ninja Run - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Ninja Run</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">177</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Ninja Run",
                    "image": "https://playgridx.com/public/uploads/thumb1739880778.png",
                    "url": "https://playgridx.com/games/ninja-run",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "177"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/ninja-run-2" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739880913.png" loading="lazy" alt="Ninja Run-2 - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Ninja Run-2</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">115</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Ninja Run-2",
                    "image": "https://playgridx.com/public/uploads/thumb1739880913.png",
                    "url": "https://playgridx.com/games/ninja-run-2",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "115"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/penalty-challenge" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739881101.png" loading="lazy" alt="Penalty Challenge - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Penalty Challenge</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">240</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Penalty Challenge",
                    "image": "https://playgridx.com/public/uploads/thumb1739881101.png",
                    "url": "https://playgridx.com/games/penalty-challenge",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "240"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/quiz-game" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739881221.png" loading="lazy" alt="Quiz Game - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Quiz Game</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">242</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Quiz Game",
                    "image": "https://playgridx.com/public/uploads/thumb1739881221.png",
                    "url": "https://playgridx.com/games/quiz-game",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "242"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/ranger-vs-zombies" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739881659.png" loading="lazy" alt="Ranger VS Zombies - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Ranger VS Zombies</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">242</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Ranger VS Zombies",
                    "image": "https://playgridx.com/public/uploads/thumb1739881659.png",
                    "url": "https://playgridx.com/games/ranger-vs-zombies",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "242"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/shoot-robbers" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739881816.png" loading="lazy" alt="Shoot Robbers - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Shoot Robbers</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">112</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Shoot Robbers",
                    "image": "https://playgridx.com/public/uploads/thumb1739881816.png",
                    "url": "https://playgridx.com/games/shoot-robbers",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "112"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/skibidi-toilet" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739881967.png" loading="lazy" alt="Skibidi Toilet - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Skibidi Toilet</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">136</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Skibidi Toilet",
                    "image": "https://playgridx.com/public/uploads/thumb1739881967.png",
                    "url": "https://playgridx.com/games/skibidi-toilet",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "136"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/snake-go" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739882107.png" loading="lazy" alt="Snake Go - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Snake Go</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">316</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Snake Go",
                    "image": "https://playgridx.com/public/uploads/thumb1739882107.png",
                    "url": "https://playgridx.com/games/snake-go",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "316"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/speed-boat" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739882217.png" loading="lazy" alt="Speed Boat - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Speed Boat</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">237</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Speed Boat",
                    "image": "https://playgridx.com/public/uploads/thumb1739882217.png",
                    "url": "https://playgridx.com/games/speed-boat",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "237"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/stick-man" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739882394.png" loading="lazy" alt="Stick Man - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Stick Man</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">121</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Stick Man",
                    "image": "https://playgridx.com/public/uploads/thumb1739882394.png",
                    "url": "https://playgridx.com/games/stick-man",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "121"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/strike-bowling" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739882513.png" loading="lazy" alt="Strike Bowling - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Strike Bowling</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">117</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Strike Bowling",
                    "image": "https://playgridx.com/public/uploads/thumb1739882513.png",
                    "url": "https://playgridx.com/games/strike-bowling",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "117"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/tank-defender" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739882672.png" loading="lazy" alt="Tank Defender - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Tank Defender</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">187</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Tank Defender",
                    "image": "https://playgridx.com/public/uploads/thumb1739882672.png",
                    "url": "https://playgridx.com/games/tank-defender",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "187"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/tank-wars" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739882829.png" loading="lazy" alt="Tank Wars - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Tank Wars</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">72</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Tank Wars",
                    "image": "https://playgridx.com/public/uploads/thumb1739882829.png",
                    "url": "https://playgridx.com/games/tank-wars",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "72"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/water-color-sort" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739882939.png" loading="lazy" alt="Water Color Sort - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Water Color Sort</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">189</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Water Color Sort",
                    "image": "https://playgridx.com/public/uploads/thumb1739882939.png",
                    "url": "https://playgridx.com/games/water-color-sort",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "189"
                    }
                }
                </script>
                            <div class="col-6 col-md-4 col-lg-3 d-flex justify-content-center mb-40  wow fadeInUp" data-wow-duration="0.3s" data-wow-delay="0.3s">
                    <a href="https://playgridx.com/games/zombie-shooter" class="game-card">
                        <div class="post-card gamecard">
                            <div class="post-card__thumb">
                                <img src="https://playgridx.com/public/uploads/thumb1739883384.png" loading="lazy" alt="Zombie Shooter - Play Now">
                            </div>
                            <div class="post-card__content">
                                <h5 class="post-title">Zombie Shooter</h5>
                                <div class="group d-flex align-items-center justify-content-start">
                                    <img src="https://playgridx.com/public/web/assets/images/elements/time.png" alt="Group Icon" class="img3 img-fluid" style="margin-bottom: 6px;margin-right: 10px;">
                                    <p class="text" style="font-size: 26px;">342</p>
                                </div>
                            </div>
                        </div>
                    </a>
                </div>
                <script type="application/ld+json">
                {
                    "@context": "https://schema.org",
                    "@type": "VideoGame",
                    "name": "Zombie Shooter",
                    "image": "https://playgridx.com/public/uploads/thumb1739883384.png",
                    "url": "https://playgridx.com/games/zombie-shooter",
                    "applicationCategory": "Game",
                    "operatingSystem": "Web",
                    "aggregateRating": {
                        "@type": "AggregateRating",
                        "ratingValue": "4.5",
                        "reviewCount": "342"
                    }
                }
                </script>
                    </div>
    </div>
</section>



        <!-- <section class="pt-120 pb-90">
          <div class="container">
            <div class="row">
              <div class="col-lg-4">
                <div class="section-header has--bg style--two">
                  <div class="header-image style--two"><img src="https://playgridx.com/public/web/assets/images/elements/header-el-4.png" alt="image"></div>
                  <span class="section-sub-title">RECENT POSTS</span>
                  <h2 class="section-title">Game News</h2>
                </div>
                <a href="blog-one.html" class="cmn-btn">View All posts</a>
              </div>
              <div class="col-lg-8 mt-lg-0 mt-5">
                <div class="blog-slider">
                  <div class="post-card">
                    <div class="post-card__thumb">
                      <img src="https://playgridx.com/public/web/assets/images/blog/1.jpg" alt="image">
                    </div>
                    <div class="post-card__content">
                      <span class="date">Sep 15, 2020</span>
                      <h3 class="post-title"><a href="blog-details.html">Benefits of Gaming - PC and Video Games</a></h3>
                      <div class="post-author mt-3">
                        <div class="post-author__thumb">
                          <img src="https://playgridx.com/public/web/assets/images/blog/author.png" alt="image">
                        </div>
                        <a href="#0" class="post-author__name">Andres Todd</a>
                      </div>
                    </div>
                  </div>
                  <div class="post-card">
                    <div class="post-card__thumb">
                      <img src="https://playgridx.com/public/web/assets/images/blog/2.jpg" alt="image">
                    </div>
                    <div class="post-card__content">
                      <a href="#0" class="post-type"><i class="las la-file-alt"></i></a>
                      <span class="date">Sep 15, 2020</span>
                      <h3 class="post-title"><a href="blog-details.html">Benefits of Gaming - PC and Video Games</a></h3>
                      <div class="post-author mt-3">
                        <div class="post-author__thumb">
                          <img src="https://playgridx.com/public/web/assets/images/blog/author.png" alt="image">
                        </div>
                        <a href="#0" class="post-author__name">Andres Todd</a>
                      </div>
                    </div>
                  </div>
                  <div class="post-card">
                    <div class="post-card__thumb">
                      <img src="https://playgridx.com/public/web/assets/images/blog/1.jpg" alt="image">
                    </div>
                    <div class="post-card__content">
                      <span class="date">Sep 15, 2020</span>
                      <h3 class="post-title"><a href="blog-details.html">Benefits of Gaming - PC and Video Games</a></h3>
                      <div class="post-author mt-3">
                        <div class="post-author__thumb">
                          <img src="https://playgridx.com/public/web/assets/images/blog/author.png" alt="image">
                        </div>
                        <a href="#0" class="post-author__name">Andres Todd</a>
                      </div>
                    </div>
                  </div>
                  <div class="post-card">
                    <div class="post-card__thumb">
                      <img src="https://playgridx.com/public/web/assets/images/blog/2.jpg" alt="image">
                    </div>
                    <div class="post-card__content">
                      <a href="#0" class="post-type"><i class="las la-file-alt"></i></a>
                      <span class="date">Sep 15, 2020</span>
                      <h3 class="post-title"><a href="blog-details.html">Benefits of Gaming - PC and Video Games</a></h3>
                      <div class="post-author mt-3">
                        <div class="post-author__thumb">
                          <img src="https://playgridx.com/public/web/assets/images/blog/author.png" alt="image">
                        </div>
                        <a href="#0" class="post-author__name">Andres Todd</a>
                      </div>
                    </div>
                  </div>
                </div>
              </div>
            </div>
          </div>
        </section> -->






        <!-- footer section start  -->
        <!-- <footer class="footer-section bg_img" data-background="https://playgridx.com/public/web/assets/images/elements/footer.png"> -->
        <footer class="footer-section" style="background-color: #e52a5f;">
          <div class="container">

            <!-- <div class="row footer-top mb-none-50">
              <div class="col-lg-3 col-sm-6 mb-50">
                <div class="footer-widget">
                  <h3 class="footer-widget__title">ABOUT</h3>
                  <ul class="short-links">
                    <li><a href="#0">About Us</a></li>
                    <li><a href="#0">Contact Us</a></li>
                    <li><a href="#0">Customer Reviews</a></li>
                    <li><a href="#0">Privacy Policy</a></li>
                  </ul>
                </div>
              </div>
              <div class="col-lg-3 col-sm-6 mb-50">
                <div class="footer-widget">
                  <h3 class="footer-widget__title">MY ACCOUNT</h3>
                  <ul class="short-links">
                    <li><a href="#0">Manage Your Account</a></li>
                    <li><a href="#0">Account Varification</a></li>
                    <li><a href="#0">Safety & Security</a></li>
                  </ul>
                </div>
              </div>
              <div class="col-lg-3 col-sm-6 mb-50">
                <div class="footer-widget">
                  <h3 class="footer-widget__title">HELP CENTER</h3>
                  <ul class="short-links">
                    <li><a href="#0">Help centre</a></li>
                    <li><a href="#0">FAQ</a></li>
                    <li><a href="#0">Quick Start Guide</a></li>
                    <li><a href="#0">Tutorials</a></li>
                  </ul>
                </div>
              </div>
              <div class="col-lg-3 col-sm-6 mb-50">
                <div class="footer-widget">
                  <h3 class="footer-widget__title">LEGAL INFO</h3>
                  <ul class="short-links">
                    <li><a href="#0">Security</a></li>
                    <li><a href="#0">Terms of Service</a></li>
                    <li><a href="#0">Become Affiliate</a></li>
                    <li><a href="#0">Complaints Policy</a></li>
                  </ul>
                </div>
              </div>
            </div> -->
            <div class="row footer-bottom align-items-center" style="padding: 14px;">
              <div class="col-lg-7 col-md-6 text-md-left text-center">
                <p class="copy-right-text" style="color: #f1f3f2;">Copyright © 2024. All Rights Reserved By PlayGrid-X</p>
              </div>
            </div>
          </div>
        </footer>

    </div>
    <!-- page-wrapper end -->
    <!-- jQuery library -->
    <script src="https://playgridx.com/public/web/assets/js/vendor/jquery-3.5.1.min.js"></script>
    <!-- bootstrap js -->
    <script src="https://playgridx.com/public/web/assets/js/vendor/bootstrap.bundle.min.js"></script>
    <!-- custom select js -->
    <script src="https://playgridx.com/public/web/assets/js/vendor/jquery.nice-select.min.js"></script>
    <!-- lightcase js -->
    <script src="https://playgridx.com/public/web/assets/js/vendor/lightcase.js"></script>
    <!-- wow js -->
    <script src="https://playgridx.com/public/web/assets/js/vendor/wow.min.js"></script>
    <!-- slick slider js -->
    <script src="https://playgridx.com/public/web/assets/js/vendor/slick.min.js"></script>
    <script src="https://playgridx.com/public/web/assets/js/vendor/TweenMax.min.js"></script>
    <!-- contact js -->
    <script src="https://playgridx.com/public/web/assets/js/contact.js"></script>

    <script src="https://playgridx.com/public/web/assets/js/vendor/jquery.paroller.min.js"></script>

    <!-- custom js -->
    <script src="https://playgridx.com/public/web/assets/js/app.js"></script>

    <script>
function myFunction() {
  // Declare variables
  var input, filter, ul, li, a, i, txtValue;
  input = document.getElementById('search');
  filter = input.value.toUpperCase();
  ul = document.getElementById("searchUL");
  if(filter){
        $('#searchUL').show();
    }else{
        $('#searchUL').hide();
    }
  li = ul.getElementsByTagName('li');

  // Loop through all list items, and hide those who don't match the search query
  for (i = 0; i < li.length; i++) {
    a = li[i].getElementsByTagName("a")[0];
    txtValue = a.textContent || a.innerText;
    if (txtValue.toUpperCase().indexOf(filter) > -1) {
      li[i].style.display = "";
    } else {
      li[i].style.display = "none";
    }
  }
}
</script>
</body>
</html>

"""

# Step 2: Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html_content, "html.parser")

# Step 3: Extract the game titles
titles = [h5.text.strip() for h5 in soup.find_all("h5", class_="post-title")]

# Step 4: Print out the extracted game titles
if titles:
    print("✅ Found game titles:")
    for title in titles:
        print("-", title)
else:
    print("❌ No game titles found.")
# Out:
# ✅ Found game titles:
# - Air Battle Mission
# - Balloonpop
# - Block Bracker
# - Brick Out
# - Car Parking Jam 3D
# - Crazy Runner
# - Fantasy Forest
# - Fishing Frenzy
# - Flight Simulator
# - Four Colors
# - Girl DressUp
# - Knife Hit Emoji
# - Ludo Multiplayer
# - Mad Shark
# - Ninja Run
# - Ninja Run-2
# - Penalty Challenge
# - Quiz Game
# - Ranger VS Zombies
# - Shoot Robbers
# - Skibidi Toilet
# - Snake Go
# - Speed Boat
# - Stick Man
# - Strike Bowling
# - Tank Defender
# - Tank Wars
# - Water Color Sort
# - Zombie Shooter
